# %% [markdown]
# <a href="https://colab.research.google.com/github/Mathew057/CS-6301-CNNs/blob/master/ResNet_Plain.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Libraries/Config

# %%
# %tensorflow_version 2.x
import tensorflow as tf
from tensorflow import keras
import numpy as np
import tensorflow_datasets as tfds
import math
import matplotlib.pyplot as plt
from tensorflow.keras.layers import Conv2D, BatchNormalization, Activation, GlobalAveragePooling2D, Dense

device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))

gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Select the Runtime → "Change runtime type" menu to enable a GPU accelerator, ')
  print('and then re-execute this cell.')
else:
  print(gpu_info)
# Out:
# Found GPU at: /device:GPU:0
# Sat Apr 11 00:33:56 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.64.00    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   34C    P0    30W / 250W |    685MiB / 16280MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %% [markdown]
# #Hyperparameters

# %%
# data
DATA_NUM_CLASSES        = 10
DATA_CHANNELS           = 3
DATA_ROWS               = 32
DATA_COLS               = 32
DATA_CROP_ROWS          = 28
DATA_CROP_COLS          = 28
DATA_MEAN               = np.array([[[125.30691805, 122.95039414, 113.86538318]]]) # CIFAR10
DATA_STD_DEV            = np.array([[[ 62.99321928,  62.08870764,  66.70489964]]]) # CIFAR10

# training
BATCH_SIZE      = 32
SHUFFLE_BUFFER  = 5000

MODEL_NUM_LAYERS=20

TRAINING_BN_MOMENTUM     = 0.99
TRAINING_BN_EPSILON      = 0.001

TRAINING_LR_MAX          = 0.001
TRAINING_LR_INIT_SCALE   = 0.01
TRAINING_LR_INIT_EPOCHS  = 5
TRAINING_LR_FINAL_SCALE  = 0.01
TRAINING_LR_FINAL_EPOCHS = 25

# training (derived)
TRAINING_NUM_EPOCHS = TRAINING_LR_INIT_EPOCHS + TRAINING_LR_FINAL_EPOCHS
TRAINING_LR_INIT    = TRAINING_LR_MAX*TRAINING_LR_INIT_SCALE
TRAINING_LR_FINAL   = TRAINING_LR_MAX*TRAINING_LR_FINAL_SCALE

# saving
SAVE_MODEL_PATH = './save/model/'
# !mkdir -p "$SAVE_MODEL_PATH"

# %% [markdown]
# #Load Datasets

# %%
AUTOTUNE=tf.data.experimental.AUTOTUNE

# pre processing for training data
def pre_processing_train(example):

    # extract image and label from example
    image = example["image"]
    label = example["label"]
  
    # image is cast to float32, normalized, augmented and random cropped
    # label is cast to int32
    image = tf.math.divide(tf.math.subtract(tf.dtypes.cast(image, tf.float32), DATA_MEAN), DATA_STD_DEV)
    image = tf.image.random_flip_left_right(image)
    image = tf.image.random_crop(image, size=[DATA_CROP_ROWS, DATA_CROP_COLS, 3])
    label = tf.dtypes.cast(label, tf.int32)
    
    # return image and label
    return image, label

# pre processing for testing data
def pre_processing_test(example):

    # extract image and label from example
    image = example["image"]
    label = example["label"]

    # image is cast to float32, normalized, augmented and center cropped
    # label is cast to int32
    image = tf.math.divide(tf.math.subtract(tf.dtypes.cast(image, tf.float32), DATA_MEAN), DATA_STD_DEV)
    image = tf.image.crop_to_bounding_box(image, (DATA_ROWS - DATA_CROP_ROWS) // 2, (DATA_COLS - DATA_CROP_COLS) // 2, DATA_CROP_ROWS, DATA_CROP_COLS)
    label = tf.dtypes.cast(label, tf.int32)
    
    # return image and label
    return image, label

# download data and split into training and testing datasets
dataset_train = tfds.load("cifar10", split=tfds.Split.TRAIN)

# transform training dataset
dataset_train = dataset_train.map(pre_processing_train, num_parallel_calls=AUTOTUNE)
dataset_train = dataset_train.shuffle(buffer_size=SHUFFLE_BUFFER)
dataset_train = dataset_train.batch(BATCH_SIZE)
dataset_train = dataset_train.prefetch(AUTOTUNE)


dataset_test = tfds.load("cifar10", split=tfds.Split.TEST)

# transform testing dataset
dataset_test = dataset_test.map(pre_processing_test, num_parallel_calls=AUTOTUNE)
dataset_test = dataset_test.batch(BATCH_SIZE)
dataset_test = dataset_test.prefetch(AUTOTUNE)

# %% [markdown]
# #Setup Model

# %%
# learning rate schedule
def lr_schedule(epoch):

    # staircase
    # lr = TRAINING_LR_MAX*math.pow(TRAINING_LR_SCALE, math.floor(epoch/TRAINING_LR_EPOCHS))

    # linear warmup followed by cosine decay
    if epoch < TRAINING_LR_INIT_EPOCHS:
        lr = (TRAINING_LR_MAX - TRAINING_LR_INIT)*(float(epoch)/TRAINING_LR_INIT_EPOCHS) + TRAINING_LR_INIT
    else:
        lr = (TRAINING_LR_MAX - TRAINING_LR_FINAL)*max(0.0, math.cos(((float(epoch) - TRAINING_LR_INIT_EPOCHS)/(TRAINING_LR_FINAL_EPOCHS - 1.0))*(math.pi/2.0))) + TRAINING_LR_FINAL

    # debug - learning rate display
    # print(epoch)
    # print(lr)

    return lr
    
def resnet_layer(inputs, num_filters=16, kernel_size=3,
                 strides=1, activation='relu', batch_normalization=True,
                 conv_first=True):
    
    conv = Conv2D(num_filters, kernel_size=kernel_size, strides=strides, padding='same')

    x = inputs
    if conv_first:
        x = conv(x)
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
    else:
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
        x = conv(x)
    return x


# create and compile model
def create_model(rows, cols, channels, num_classes, lr_initial, depth):
    num_filters = 16
    num_res_blocks = int((depth - 2) / 6)
    # encoder - input
    model_input = keras.Input(shape=(rows, cols, channels), name='input_image')
    x           = model_input
    
    x = resnet_layer(inputs=x)
    # Instantiate the stack of residual units
    for stack in range(3):
        for res_block in range(num_res_blocks):
            
            strides = 1
            if stack > 0 and res_block == 0:  # first layer but not first stack
                strides = 2  # downsample
                
            x = resnet_layer(inputs=x,
                             num_filters=num_filters, strides=strides)
            x = resnet_layer(inputs=x,
                             num_filters=num_filters)
        num_filters *= 2

    # encoder - output
    encoder_output = x

    # decoder
    y              = GlobalAveragePooling2D()(encoder_output)
    decoder_output = Dense(num_classes, activation='softmax')(y)

    # forward path
    model = keras.Model(inputs=model_input, outputs=decoder_output, name='resnetv2_model')

    # loss, backward path (implicit) and weight update
    model.compile(optimizer=tf.keras.optimizers.Adam(lr_initial), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

    # return model
    return model

# create and compile model
model = create_model(DATA_CROP_ROWS, DATA_CROP_COLS, DATA_CHANNELS, DATA_NUM_CLASSES, TRAINING_LR_MAX, MODEL_NUM_LAYERS)

# model description and figure
model.summary()
# keras.utils.plot_model(model, 'cifar_model.png', show_shapes=True)
# Out:
# Model: "resnetv2_model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_image (InputLayer)     [(None, 28, 28, 3)]       0
# _________________________________________________________________
# conv2d_38 (Conv2D)           (None, 28, 28, 16)        448
# _________________________________________________________________
# batch_normalization_38 (Batc (None, 28, 28, 16)        64
# _________________________________________________________________
# activation_47 (Activation)   (None, 28, 28, 16)        0
# _________________________________________________________________
# conv2d_39 (Conv2D)           (None, 28, 28, 16)        2320
# _________________________________________________________________
# batch_normalization_39 (Batc (None, 28, 28, 16)        64
# _________________________________________________________________
# activation_48 (Activation)   (None, 28, 28, 16)        0
# _________________________________________________________________
# conv2d_40 (Conv2D)           (None, 28, 28, 16)        2320
# _________________________________________________________________
# batch_normalization_40 (Batc (None, 28, 28, 16)        64
# _________________________________________________________________
# activation_49 (Activation)   (None, 28, 28, 16)        0
# _________________________________________________________________
# conv2d_41 (Conv2D)           (None, 28, 28, 16)        2320
# _________________________________________________________________
# batch_normalization_41 (Batc (None, 28, 28, 16)        64
# _________________________________________________________________
# activation_50 (Activation)   (None, 28, 28, 16)        0
# _________________________________________________________________
# conv2d_42 (Conv2D)           (None, 28, 28, 16)        2320
# _________________________________________________________________
# batch_normalization_42 (Batc (None, 28, 28, 16)        64
# _________________________________________________________________
# activation_51 (Activation)   (None, 28, 28, 16)        0
# _________________________________________________________________
# conv2d_43 (Conv2D)           (None, 28, 28, 16)        2320
# _________________________________________________________________
# batch_normalization_43 (Batc (None, 28, 28, 16)        64
# _________________________________________________________________
# activation_52 (Activation)   (None, 28, 28, 16)        0
# _________________________________________________________________
# conv2d_44 (Conv2D)           (None, 28, 28, 16)        2320
# _________________________________________________________________
# batch_normalization_44 (Batc (None, 28, 28, 16)        64
# _________________________________________________________________
# activation_53 (Activation)   (None, 28, 28, 16)        0
# _________________________________________________________________
# conv2d_45 (Conv2D)           (None, 14, 14, 32)        4640
# _________________________________________________________________
# batch_normalization_45 (Batc (None, 14, 14, 32)        128
# _________________________________________________________________
# activation_54 (Activation)   (None, 14, 14, 32)        0
# _________________________________________________________________
# conv2d_46 (Conv2D)           (None, 14, 14, 32)        9248
# _________________________________________________________________
# batch_normalization_46 (Batc (None, 14, 14, 32)        128
# _________________________________________________________________
# activation_55 (Activation)   (None, 14, 14, 32)        0
# _________________________________________________________________
# conv2d_47 (Conv2D)           (None, 14, 14, 32)        9248
# _________________________________________________________________
# batch_normalization_47 (Batc (None, 14, 14, 32)        128
# _________________________________________________________________
# activation_56 (Activation)   (None, 14, 14, 32)        0
# _________________________________________________________________
# conv2d_48 (Conv2D)           (None, 14, 14, 32)        9248
# _________________________________________________________________
# batch_normalization_48 (Batc (None, 14, 14, 32)        128
# _________________________________________________________________
# activation_57 (Activation)   (None, 14, 14, 32)        0
# _________________________________________________________________
# conv2d_49 (Conv2D)           (None, 14, 14, 32)        9248
# _________________________________________________________________
# batch_normalization_49 (Batc (None, 14, 14, 32)        128
# _________________________________________________________________
# activation_58 (Activation)   (None, 14, 14, 32)        0
# _________________________________________________________________
# conv2d_50 (Conv2D)           (None, 14, 14, 32)        9248
# _________________________________________________________________
# batch_normalization_50 (Batc (None, 14, 14, 32)        128
# _________________________________________________________________
# activation_59 (Activation)   (None, 14, 14, 32)        0
# _________________________________________________________________
# conv2d_51 (Conv2D)           (None, 7, 7, 64)          18496
# _________________________________________________________________
# batch_normalization_51 (Batc (None, 7, 7, 64)          256
# _________________________________________________________________
# activation_60 (Activation)   (None, 7, 7, 64)          0
# _________________________________________________________________
# conv2d_52 (Conv2D)           (None, 7, 7, 64)          36928
# _________________________________________________________________
# batch_normalization_52 (Batc (None, 7, 7, 64)          256
# _________________________________________________________________
# activation_61 (Activation)   (None, 7, 7, 64)          0
# _________________________________________________________________
# conv2d_53 (Conv2D)           (None, 7, 7, 64)          36928
# _________________________________________________________________
# batch_normalization_53 (Batc (None, 7, 7, 64)          256
# _________________________________________________________________
# activation_62 (Activation)   (None, 7, 7, 64)          0
# _________________________________________________________________
# conv2d_54 (Conv2D)           (None, 7, 7, 64)          36928
# _________________________________________________________________
# batch_normalization_54 (Batc (None, 7, 7, 64)          256
# _________________________________________________________________
# activation_63 (Activation)   (None, 7, 7, 64)          0
# _________________________________________________________________
# conv2d_55 (Conv2D)           (None, 7, 7, 64)          36928
# _________________________________________________________________
# batch_normalization_55 (Batc (None, 7, 7, 64)          256
# _________________________________________________________________
# activation_64 (Activation)   (None, 7, 7, 64)          0
# _________________________________________________________________
# conv2d_56 (Conv2D)           (None, 7, 7, 64)          36928
# _________________________________________________________________
# batch_normalization_56 (Batc (None, 7, 7, 64)          256
# _________________________________________________________________
# activation_65 (Activation)   (None, 7, 7, 64)          0
# _________________________________________________________________
# global_average_pooling2d_2 ( (None, 64)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                650
# =================================================================
# Total params: 271,786
# Trainable params: 270,410
# Non-trainable params: 1,376
# _________________________________________________________________

# %% [markdown]
# #Train

# %%
# callbacks (learning rate schedule, model checkpointing during training)
callbacks = [keras.callbacks.LearningRateScheduler(lr_schedule),
             keras.callbacks.ModelCheckpoint(filepath=SAVE_MODEL_PATH+'model_{epoch}.h5', save_best_only=True, monitor='val_loss', verbose=1)]

# training
initial_epoch_num = 0
history           = model.fit(x=dataset_train, epochs=TRAINING_NUM_EPOCHS, verbose=1, callbacks=callbacks, validation_data=dataset_test, initial_epoch=initial_epoch_num)

# example of restarting training after a crash from the last saved checkpoint
# model.load_weights(SAVE_MODEL_PATH+'model_X.h5') # replace X with the last saved checkpoint number
# initial_epoch_num = X                            # replace X with the last saved checkpoint number
# history           = model.fit(x=dataset_train, epochs=TRAINING_NUM_EPOCHS, verbose=1, callbacks=callbacks, validation_data=dataset_test, initial_epoch=initial_epoch_num)
# Out:
# Epoch 1/60
# 1563/1563 [==============================] - ETA: 0s - loss: 2.1827 - accuracy: 0.1695
# Epoch 00001: val_loss improved from inf to 2.02412, saving model to ./save/model/model_1.h5
# 1563/1563 [==============================] - 27s 18ms/step - loss: 2.1827 - accuracy: 0.1695 - val_loss: 2.0241 - val_accuracy: 0.2289 - lr: 1.0000e-05
# Epoch 2/60
# 1560/1563 [============================>.] - ETA: 0s - loss: 1.6522 - accuracy: 0.3870
# Epoch 00002: val_loss improved from 2.02412 to 1.43011, saving model to ./save/model/model_2.h5
# 1563/1563 [==============================] - 27s 17ms/step - loss: 1.6520 - accuracy: 0.3871 - val_loss: 1.4301 - val_accuracy: 0.4736 - lr: 2.0800e-04
# Epoch 3/60
# 1559/1563 [============================>.] - ETA: 0s - loss: 1.3528 - accuracy: 0.5108
# Epoch 00003: val_loss improved from 1.43011 to 1.26099, saving model to ./save/model/model_3.h5
# 1563/1563 [==============================] - 26s 17ms/step - loss: 1.3523 - accuracy: 0.5111 - val_loss: 1.2610 - val_accuracy: 0.5454 - lr: 4.0600e-04
# Epoch 4/60
# 1560/1563 [============================>.] - ETA: 0s - loss: 1.1416 - accuracy: 0.5949
# Epoch 00004: val_loss did not improve from 1.26099
# 1563/1563 [==============================] - 26s 17ms/step - loss: 1.1418 - accuracy: 0.5949 - val_loss: 1.2842 - val_accuracy: 0.5613 - lr: 6.0400e-04
# Epoch 5/60
# 1563/1563 [==============================] - ETA: 0s - loss: 1.0056 - accuracy: 0.6482
# Epoch 00005: val_loss improved from 1.26099 to 0.96799, saving model to ./save/model/model_5.h5
# 1563/1563 [==============================] - 26s 17ms/step - loss: 1.0056 - accuracy: 0.6482 - val_loss: 0.9680 - val_accuracy: 0.6597 - lr: 8.0200e-04
# Epoch 6/60
# 1559/1563 [============================>.] - ETA: 0s - loss: 0.8956 - accuracy: 0.6862
# Epoch 00006: val_loss did not improve from 0.96799
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.8954 - accuracy: 0.6863 - val_loss: 1.5133 - val_accuracy: 0.5190 - lr: 0.0010
# Epoch 7/60
# 1558/1563 [============================>.] - ETA: 0s - loss: 0.8003 - accuracy: 0.7229
# Epoch 00007: val_loss improved from 0.96799 to 0.95442, saving model to ./save/model/model_7.h5
# 1563/1563 [==============================] - 26s 16ms/step - loss: 0.8002 - accuracy: 0.7228 - val_loss: 0.9544 - val_accuracy: 0.6825 - lr: 9.9958e-04
# Epoch 8/60
# 1560/1563 [============================>.] - ETA: 0s - loss: 0.7257 - accuracy: 0.7504
# Epoch 00008: val_loss improved from 0.95442 to 0.75564, saving model to ./save/model/model_8.h5
# 1563/1563 [==============================] - 27s 17ms/step - loss: 0.7259 - accuracy: 0.7504 - val_loss: 0.7556 - val_accuracy: 0.7399 - lr: 9.9833e-04
# Epoch 9/60
# 1558/1563 [============================>.] - ETA: 0s - loss: 0.6744 - accuracy: 0.7664
# Epoch 00009: val_loss improved from 0.75564 to 0.74889, saving model to ./save/model/model_9.h5
# 1563/1563 [==============================] - 26s 16ms/step - loss: 0.6744 - accuracy: 0.7664 - val_loss: 0.7489 - val_accuracy: 0.7446 - lr: 9.9623e-04
# Epoch 10/60
# 1557/1563 [============================>.] - ETA: 0s - loss: 0.6304 - accuracy: 0.7809
# Epoch 00010: val_loss improved from 0.74889 to 0.68101, saving model to ./save/model/model_10.h5
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.6300 - accuracy: 0.7810 - val_loss: 0.6810 - val_accuracy: 0.7701 - lr: 9.9331e-04
# Epoch 11/60
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.5975 - accuracy: 0.7937
# Epoch 00011: val_loss did not improve from 0.68101
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.5974 - accuracy: 0.7936 - val_loss: 0.7027 - val_accuracy: 0.7604 - lr: 9.8955e-04
# Epoch 12/60
# 1558/1563 [============================>.] - ETA: 0s - loss: 0.5630 - accuracy: 0.8038
# Epoch 00012: val_loss did not improve from 0.68101
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.5635 - accuracy: 0.8037 - val_loss: 0.7871 - val_accuracy: 0.7373 - lr: 9.8496e-04
# Epoch 13/60
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.5408 - accuracy: 0.8135
# Epoch 00013: val_loss improved from 0.68101 to 0.54023, saving model to ./save/model/model_13.h5
# 1563/1563 [==============================] - 27s 17ms/step - loss: 0.5408 - accuracy: 0.8135 - val_loss: 0.5402 - val_accuracy: 0.8137 - lr: 9.7955e-04
# Epoch 14/60
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.5151 - accuracy: 0.8233
# Epoch 00014: val_loss did not improve from 0.54023
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.5150 - accuracy: 0.8233 - val_loss: 0.6148 - val_accuracy: 0.7911 - lr: 9.7331e-04
# Epoch 15/60
# 1557/1563 [============================>.] - ETA: 0s - loss: 0.4888 - accuracy: 0.8316
# Epoch 00015: val_loss did not improve from 0.54023
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.4886 - accuracy: 0.8316 - val_loss: 0.5715 - val_accuracy: 0.8074 - lr: 9.6627e-04
# Epoch 16/60
# 1557/1563 [============================>.] - ETA: 0s - loss: 0.4746 - accuracy: 0.8365
# Epoch 00016: val_loss did not improve from 0.54023
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.4743 - accuracy: 0.8366 - val_loss: 0.5489 - val_accuracy: 0.8120 - lr: 9.5841e-04
# Epoch 17/60
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.4581 - accuracy: 0.8412
# Epoch 00017: val_loss improved from 0.54023 to 0.53099, saving model to ./save/model/model_17.h5
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.4583 - accuracy: 0.8412 - val_loss: 0.5310 - val_accuracy: 0.8192 - lr: 9.4975e-04
# Epoch 18/60
# 1557/1563 [============================>.] - ETA: 0s - loss: 0.4445 - accuracy: 0.8451
# Epoch 00018: val_loss improved from 0.53099 to 0.50529, saving model to ./save/model/model_18.h5
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.4442 - accuracy: 0.8451 - val_loss: 0.5053 - val_accuracy: 0.8332 - lr: 9.4030e-04
# Epoch 19/60
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.4257 - accuracy: 0.8534
# Epoch 00019: val_loss did not improve from 0.50529
# 1563/1563 [==============================] - 26s 16ms/step - loss: 0.4260 - accuracy: 0.8534 - val_loss: 0.5139 - val_accuracy: 0.8248 - lr: 9.3005e-04
# Epoch 20/60
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.4100 - accuracy: 0.8588
# Epoch 00020: val_loss improved from 0.50529 to 0.47937, saving model to ./save/model/model_20.h5
# 1563/1563 [==============================] - 27s 17ms/step - loss: 0.4102 - accuracy: 0.8589 - val_loss: 0.4794 - val_accuracy: 0.8379 - lr: 9.1903e-04
# Epoch 21/60
# 1560/1563 [============================>.] - ETA: 0s - loss: 0.4011 - accuracy: 0.8614
# Epoch 00021: val_loss did not improve from 0.47937
# 1563/1563 [==============================] - 27s 17ms/step - loss: 0.4010 - accuracy: 0.8615 - val_loss: 0.5275 - val_accuracy: 0.8277 - lr: 9.0724e-04
# Epoch 22/60
# 1557/1563 [============================>.] - ETA: 0s - loss: 0.3880 - accuracy: 0.8651
# Epoch 00022: val_loss did not improve from 0.47937
# 1563/1563 [==============================] - 27s 17ms/step - loss: 0.3879 - accuracy: 0.8652 - val_loss: 0.5470 - val_accuracy: 0.8174 - lr: 8.9470e-04
# Epoch 23/60
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.3784 - accuracy: 0.8690
# Epoch 00023: val_loss did not improve from 0.47937
# 1563/1563 [==============================] - 27s 17ms/step - loss: 0.3783 - accuracy: 0.8691 - val_loss: 0.4986 - val_accuracy: 0.8338 - lr: 8.8140e-04
# Epoch 24/60
# 1559/1563 [============================>.] - ETA: 0s - loss: 0.3629 - accuracy: 0.8758
# Epoch 00024: val_loss did not improve from 0.47937
# 1563/1563 [==============================] - 27s 18ms/step - loss: 0.3632 - accuracy: 0.8757 - val_loss: 0.6218 - val_accuracy: 0.7963 - lr: 8.6737e-04
# Epoch 25/60
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.3556 - accuracy: 0.8774
# Epoch 00025: val_loss improved from 0.47937 to 0.44993, saving model to ./save/model/model_25.h5
# 1563/1563 [==============================] - 27s 17ms/step - loss: 0.3556 - accuracy: 0.8775 - val_loss: 0.4499 - val_accuracy: 0.8481 - lr: 8.5261e-04
# Epoch 26/60
# 1559/1563 [============================>.] - ETA: 0s - loss: 0.3462 - accuracy: 0.8798
# Epoch 00026: val_loss did not improve from 0.44993
# 1563/1563 [==============================] - 28s 18ms/step - loss: 0.3461 - accuracy: 0.8798 - val_loss: 0.4807 - val_accuracy: 0.8415 - lr: 8.3713e-04
# Epoch 27/60
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.3399 - accuracy: 0.8817
# Epoch 00027: val_loss improved from 0.44993 to 0.44107, saving model to ./save/model/model_27.h5
# 1563/1563 [==============================] - 27s 17ms/step - loss: 0.3401 - accuracy: 0.8817 - val_loss: 0.4411 - val_accuracy: 0.8537 - lr: 8.2096e-04
# Epoch 28/60
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.3283 - accuracy: 0.8856
# Epoch 00028: val_loss did not improve from 0.44107
# 1563/1563 [==============================] - 28s 18ms/step - loss: 0.3282 - accuracy: 0.8857 - val_loss: 0.4464 - val_accuracy: 0.8487 - lr: 8.0410e-04
# Epoch 29/60
# 1559/1563 [============================>.] - ETA: 0s - loss: 0.3128 - accuracy: 0.8903
# Epoch 00029: val_loss did not improve from 0.44107
# 1563/1563 [==============================] - 27s 17ms/step - loss: 0.3130 - accuracy: 0.8902 - val_loss: 0.4572 - val_accuracy: 0.8513 - lr: 7.8657e-04
# Epoch 30/60
# 1558/1563 [============================>.] - ETA: 0s - loss: 0.3045 - accuracy: 0.8931
# Epoch 00030: val_loss did not improve from 0.44107
# 1563/1563 [==============================] - 27s 17ms/step - loss: 0.3048 - accuracy: 0.8930 - val_loss: 0.4538 - val_accuracy: 0.8504 - lr: 7.6838e-04
# Epoch 31/60
# 1559/1563 [============================>.] - ETA: 0s - loss: 0.2978 - accuracy: 0.8966
# Epoch 00031: val_loss did not improve from 0.44107
# 1563/1563 [==============================] - 27s 17ms/step - loss: 0.2976 - accuracy: 0.8966 - val_loss: 0.4729 - val_accuracy: 0.8462 - lr: 7.4955e-04
# Epoch 32/60
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.2947 - accuracy: 0.8985
# Epoch 00032: val_loss improved from 0.44107 to 0.44098, saving model to ./save/model/model_32.h5
# 1563/1563 [==============================] - 27s 17ms/step - loss: 0.2947 - accuracy: 0.8985 - val_loss: 0.4410 - val_accuracy: 0.8533 - lr: 7.3010e-04
# Epoch 33/60
# 1557/1563 [============================>.] - ETA: 0s - loss: 0.2829 - accuracy: 0.9018
# Epoch 00033: val_loss did not improve from 0.44098
# 1563/1563 [==============================] - 26s 16ms/step - loss: 0.2826 - accuracy: 0.9018 - val_loss: 0.4444 - val_accuracy: 0.8523 - lr: 7.1004e-04
# Epoch 34/60
# 1560/1563 [============================>.] - ETA: 0s - loss: 0.2763 - accuracy: 0.9047
# Epoch 00034: val_loss did not improve from 0.44098
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.2765 - accuracy: 0.9047 - val_loss: 0.4476 - val_accuracy: 0.8542 - lr: 6.8938e-04
# Epoch 35/60
# 1560/1563 [============================>.] - ETA: 0s - loss: 0.2690 - accuracy: 0.9056
# Epoch 00035: val_loss did not improve from 0.44098
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.2691 - accuracy: 0.9055 - val_loss: 0.4928 - val_accuracy: 0.8456 - lr: 6.6815e-04
# Epoch 36/60
# 1560/1563 [============================>.] - ETA: 0s - loss: 0.2566 - accuracy: 0.9103
# Epoch 00036: val_loss did not improve from 0.44098
# 1563/1563 [==============================] - 27s 17ms/step - loss: 0.2568 - accuracy: 0.9102 - val_loss: 0.4589 - val_accuracy: 0.8512 - lr: 6.4636e-04
# Epoch 37/60
# 1559/1563 [============================>.] - ETA: 0s - loss: 0.2552 - accuracy: 0.9104
# Epoch 00037: val_loss did not improve from 0.44098
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.2551 - accuracy: 0.9104 - val_loss: 0.4513 - val_accuracy: 0.8580 - lr: 6.2403e-04
# Epoch 38/60
# 1558/1563 [============================>.] - ETA: 0s - loss: 0.2441 - accuracy: 0.9150
# Epoch 00038: val_loss improved from 0.44098 to 0.41644, saving model to ./save/model/model_38.h5
# 1563/1563 [==============================] - 28s 18ms/step - loss: 0.2444 - accuracy: 0.9150 - val_loss: 0.4164 - val_accuracy: 0.8662 - lr: 6.0119e-04
# Epoch 39/60
# 1560/1563 [============================>.] - ETA: 0s - loss: 0.2384 - accuracy: 0.9155
# Epoch 00039: val_loss did not improve from 0.41644
# 1563/1563 [==============================] - 27s 17ms/step - loss: 0.2384 - accuracy: 0.9155 - val_loss: 0.4433 - val_accuracy: 0.8589 - lr: 5.7784e-04
# Epoch 40/60
# 1563/1563 [==============================] - ETA: 0s - loss: 0.2307 - accuracy: 0.9180
# Epoch 00040: val_loss did not improve from 0.41644
# 1563/1563 [==============================] - 28s 18ms/step - loss: 0.2307 - accuracy: 0.9180 - val_loss: 0.4469 - val_accuracy: 0.8649 - lr: 5.5401e-04
# Epoch 41/60
# 1560/1563 [============================>.] - ETA: 0s - loss: 0.2226 - accuracy: 0.9220
# Epoch 00041: val_loss improved from 0.41644 to 0.41304, saving model to ./save/model/model_41.h5
# 1563/1563 [==============================] - 27s 17ms/step - loss: 0.2225 - accuracy: 0.9220 - val_loss: 0.4130 - val_accuracy: 0.8709 - lr: 5.2973e-04
# Epoch 42/60
# 1559/1563 [============================>.] - ETA: 0s - loss: 0.2216 - accuracy: 0.9215
# Epoch 00042: val_loss did not improve from 0.41304
# 1563/1563 [==============================] - 27s 17ms/step - loss: 0.2216 - accuracy: 0.9216 - val_loss: 0.4249 - val_accuracy: 0.8632 - lr: 5.0500e-04
# Epoch 43/60
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.2055 - accuracy: 0.9268
# Epoch 00043: val_loss did not improve from 0.41304
# 1563/1563 [==============================] - 27s 17ms/step - loss: 0.2054 - accuracy: 0.9268 - val_loss: 0.4145 - val_accuracy: 0.8683 - lr: 4.7985e-04
# Epoch 44/60
# 1558/1563 [============================>.] - ETA: 0s - loss: 0.2014 - accuracy: 0.9283
# Epoch 00044: val_loss improved from 0.41304 to 0.41207, saving model to ./save/model/model_44.h5
# 1563/1563 [==============================] - 27s 17ms/step - loss: 0.2013 - accuracy: 0.9283 - val_loss: 0.4121 - val_accuracy: 0.8699 - lr: 4.5431e-04
# Epoch 45/60
# 1559/1563 [============================>.] - ETA: 0s - loss: 0.1970 - accuracy: 0.9317
# Epoch 00045: val_loss did not improve from 0.41207
# 1563/1563 [==============================] - 27s 17ms/step - loss: 0.1971 - accuracy: 0.9317 - val_loss: 0.4140 - val_accuracy: 0.8702 - lr: 4.2839e-04
# Epoch 46/60
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.1891 - accuracy: 0.9331
# Epoch 00046: val_loss did not improve from 0.41207
# 1563/1563 [==============================] - 28s 18ms/step - loss: 0.1890 - accuracy: 0.9331 - val_loss: 0.4141 - val_accuracy: 0.8706 - lr: 4.0212e-04
# Epoch 47/60
# 1560/1563 [============================>.] - ETA: 0s - loss: 0.1837 - accuracy: 0.9349
# Epoch 00047: val_loss did not improve from 0.41207
# 1563/1563 [==============================] - 27s 17ms/step - loss: 0.1839 - accuracy: 0.9349 - val_loss: 0.4238 - val_accuracy: 0.8687 - lr: 3.7551e-04
# Epoch 48/60
# 1559/1563 [============================>.] - ETA: 0s - loss: 0.1756 - accuracy: 0.9368
# Epoch 00048: val_loss did not improve from 0.41207
# 1563/1563 [==============================] - 28s 18ms/step - loss: 0.1759 - accuracy: 0.9366 - val_loss: 0.4314 - val_accuracy: 0.8649 - lr: 3.4860e-04
# Epoch 49/60
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.1713 - accuracy: 0.9395
# Epoch 00049: val_loss improved from 0.41207 to 0.40567, saving model to ./save/model/model_49.h5
# 1563/1563 [==============================] - 28s 18ms/step - loss: 0.1713 - accuracy: 0.9395 - val_loss: 0.4057 - val_accuracy: 0.8758 - lr: 3.2140e-04
# Epoch 50/60
# 1559/1563 [============================>.] - ETA: 0s - loss: 0.1656 - accuracy: 0.9414
# Epoch 00050: val_loss did not improve from 0.40567
# 1563/1563 [==============================] - 27s 18ms/step - loss: 0.1656 - accuracy: 0.9415 - val_loss: 0.4136 - val_accuracy: 0.8763 - lr: 2.9394e-04
# Epoch 51/60
# 1563/1563 [==============================] - ETA: 0s - loss: 0.1588 - accuracy: 0.9441
# Epoch 00051: val_loss did not improve from 0.40567
# 1563/1563 [==============================] - 28s 18ms/step - loss: 0.1588 - accuracy: 0.9441 - val_loss: 0.4107 - val_accuracy: 0.8773 - lr: 2.6623e-04
# Epoch 52/60
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.1546 - accuracy: 0.9457
# Epoch 00052: val_loss improved from 0.40567 to 0.40397, saving model to ./save/model/model_52.h5
# 1563/1563 [==============================] - 28s 18ms/step - loss: 0.1547 - accuracy: 0.9457 - val_loss: 0.4040 - val_accuracy: 0.8773 - lr: 2.3831e-04
# Epoch 53/60
# 1563/1563 [==============================] - ETA: 0s - loss: 0.1483 - accuracy: 0.9470
# Epoch 00053: val_loss improved from 0.40397 to 0.40365, saving model to ./save/model/model_53.h5
# 1563/1563 [==============================] - 28s 18ms/step - loss: 0.1483 - accuracy: 0.9470 - val_loss: 0.4036 - val_accuracy: 0.8777 - lr: 2.1020e-04
# Epoch 54/60
# 1560/1563 [============================>.] - ETA: 0s - loss: 0.1437 - accuracy: 0.9495
# Epoch 00054: val_loss did not improve from 0.40365
# 1563/1563 [==============================] - 28s 18ms/step - loss: 0.1440 - accuracy: 0.9494 - val_loss: 0.4088 - val_accuracy: 0.8774 - lr: 1.8191e-04
# Epoch 55/60
# 1558/1563 [============================>.] - ETA: 0s - loss: 0.1369 - accuracy: 0.9519
# Epoch 00055: val_loss did not improve from 0.40365
# 1563/1563 [==============================] - 27s 17ms/step - loss: 0.1372 - accuracy: 0.9519 - val_loss: 0.4051 - val_accuracy: 0.8774 - lr: 1.5348e-04
# Epoch 56/60
# 1558/1563 [============================>.] - ETA: 0s - loss: 0.1299 - accuracy: 0.9543
# Epoch 00056: val_loss improved from 0.40365 to 0.39793, saving model to ./save/model/model_56.h5
# 1563/1563 [==============================] - 27s 18ms/step - loss: 0.1299 - accuracy: 0.9544 - val_loss: 0.3979 - val_accuracy: 0.8795 - lr: 1.2493e-04
# Epoch 57/60
# 1560/1563 [============================>.] - ETA: 0s - loss: 0.1278 - accuracy: 0.9551
# Epoch 00057: val_loss improved from 0.39793 to 0.39465, saving model to ./save/model/model_57.h5
# 1563/1563 [==============================] - 28s 18ms/step - loss: 0.1278 - accuracy: 0.9551 - val_loss: 0.3947 - val_accuracy: 0.8809 - lr: 9.6284e-05
# Epoch 58/60
# 1563/1563 [==============================] - ETA: 0s - loss: 0.1231 - accuracy: 0.9563
# Epoch 00058: val_loss improved from 0.39465 to 0.39364, saving model to ./save/model/model_58.h5
# 1563/1563 [==============================] - 28s 18ms/step - loss: 0.1231 - accuracy: 0.9563 - val_loss: 0.3936 - val_accuracy: 0.8809 - lr: 6.7563e-05
# Epoch 59/60
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.1209 - accuracy: 0.9569
# Epoch 00059: val_loss improved from 0.39364 to 0.39090, saving model to ./save/model/model_59.h5
# 1563/1563 [==============================] - 27s 17ms/step - loss: 0.1208 - accuracy: 0.9569 - val_loss: 0.3909 - val_accuracy: 0.8821 - lr: 3.8794e-05
# Epoch 60/60
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.1173 - accuracy: 0.9591
# Epoch 00060: val_loss improved from 0.39090 to 0.39041, saving model to ./save/model/model_60.h5
# 1563/1563 [==============================] - 27s 17ms/step - loss: 0.1174 - accuracy: 0.9591 - val_loss: 0.3904 - val_accuracy: 0.8819 - lr: 1.0000e-05

# %% [markdown]
# #Plots

# %%
# training and validation data accuracy
acc     = history.history['accuracy']
val_acc = history.history['val_accuracy']

# training and validation data loss
loss     = history.history['loss']
val_loss = history.history['val_loss']

# plot accuracy
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.xlabel('epoch')
plt.ylim([min(plt.ylim()), 1])
plt.title('Training and Validation Accuracy')
plt.show()

plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0, 2.0])
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()

plt.plot([lr_schedule(epoch) for epoch in range(TRAINING_NUM_EPOCHS)])
plt.ylabel('Learning Rate')
plt.xlabel('epoch')
plt.title("Learning Rate/Epoch")
plt.show()

# %% [markdown]
# #Size Comparison

# %%
# callbacks (learning rate schedule, model checkpointing during training)
callbacks = [keras.callbacks.LearningRateScheduler(lr_schedule)]

model = create_model(DATA_CROP_ROWS, DATA_CROP_COLS, DATA_CHANNELS, DATA_NUM_CLASSES, TRAINING_LR_MAX, 20)
history_20           = model.fit(x=dataset_train, epochs=TRAINING_NUM_EPOCHS, verbose=1, callbacks=callbacks, validation_data=dataset_test, initial_epoch=initial_epoch_num)


model = create_model(DATA_CROP_ROWS, DATA_CROP_COLS, DATA_CHANNELS, DATA_NUM_CLASSES, TRAINING_LR_MAX, 56)
history_56           = model.fit(x=dataset_train, epochs=TRAINING_NUM_EPOCHS, verbose=1, callbacks=callbacks, validation_data=dataset_test, initial_epoch=initial_epoch_num)
# Out:
# Epoch 1/30
# 1563/1563 [==============================] - 29s 19ms/step - loss: 2.2692 - accuracy: 0.1405 - val_loss: 2.1904 - val_accuracy: 0.1728 - lr: 1.0000e-05
# Epoch 2/30
# 1563/1563 [==============================] - 29s 18ms/step - loss: 1.6233 - accuracy: 0.4062 - val_loss: 1.4027 - val_accuracy: 0.4897 - lr: 2.0800e-04
# Epoch 3/30
# 1563/1563 [==============================] - 28s 18ms/step - loss: 1.3290 - accuracy: 0.5198 - val_loss: 1.2978 - val_accuracy: 0.5383 - lr: 4.0600e-04
# Epoch 4/30
# 1563/1563 [==============================] - 28s 18ms/step - loss: 1.1384 - accuracy: 0.5948 - val_loss: 1.2988 - val_accuracy: 0.5476 - lr: 6.0400e-04
# Epoch 5/30
# 1563/1563 [==============================] - 28s 18ms/step - loss: 1.0052 - accuracy: 0.6456 - val_loss: 1.0465 - val_accuracy: 0.6435 - lr: 8.0200e-04
# Epoch 6/30
# 1563/1563 [==============================] - 27s 18ms/step - loss: 0.8972 - accuracy: 0.6852 - val_loss: 1.0237 - val_accuracy: 0.6645 - lr: 0.0010
# Epoch 7/30
# 1563/1563 [==============================] - 28s 18ms/step - loss: 0.8016 - accuracy: 0.7217 - val_loss: 0.8688 - val_accuracy: 0.7100 - lr: 9.9788e-04
# Epoch 8/30
# 1563/1563 [==============================] - 28s 18ms/step - loss: 0.7341 - accuracy: 0.7456 - val_loss: 0.7998 - val_accuracy: 0.7251 - lr: 9.9153e-04
# Epoch 9/30
# 1563/1563 [==============================] - 27s 17ms/step - loss: 0.6781 - accuracy: 0.7675 - val_loss: 0.7109 - val_accuracy: 0.7553 - lr: 9.8098e-04
# Epoch 10/30
# 1563/1563 [==============================] - 28s 18ms/step - loss: 0.6341 - accuracy: 0.7811 - val_loss: 0.7764 - val_accuracy: 0.7468 - lr: 9.6627e-04
# Epoch 11/30
# 1563/1563 [==============================] - 27s 17ms/step - loss: 0.5962 - accuracy: 0.7946 - val_loss: 0.7381 - val_accuracy: 0.7509 - lr: 9.4746e-04
# Epoch 12/30
# 1563/1563 [==============================] - 27s 17ms/step - loss: 0.5617 - accuracy: 0.8074 - val_loss: 0.6000 - val_accuracy: 0.7981 - lr: 9.2464e-04
# Epoch 13/30
# 1563/1563 [==============================] - 27s 17ms/step - loss: 0.5295 - accuracy: 0.8176 - val_loss: 0.5406 - val_accuracy: 0.8128 - lr: 8.9790e-04
# Epoch 14/30
# 1563/1563 [==============================] - 27s 18ms/step - loss: 0.5059 - accuracy: 0.8268 - val_loss: 0.5979 - val_accuracy: 0.7967 - lr: 8.6737e-04
# Epoch 15/30
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.4762 - accuracy: 0.8357 - val_loss: 0.5202 - val_accuracy: 0.8248 - lr: 8.3315e-04
# Epoch 16/30
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.4627 - accuracy: 0.8396 - val_loss: 0.5103 - val_accuracy: 0.8260 - lr: 7.9542e-04
# Epoch 17/30
# 1563/1563 [==============================] - 26s 16ms/step - loss: 0.4350 - accuracy: 0.8523 - val_loss: 0.5839 - val_accuracy: 0.8037 - lr: 7.5432e-04
# Epoch 18/30
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.4212 - accuracy: 0.8558 - val_loss: 0.4766 - val_accuracy: 0.8371 - lr: 7.1004e-04
# Epoch 19/30
# 1563/1563 [==============================] - 26s 16ms/step - loss: 0.4011 - accuracy: 0.8611 - val_loss: 0.4967 - val_accuracy: 0.8313 - lr: 6.6275e-04
# Epoch 20/30
# 1563/1563 [==============================] - 25s 16ms/step - loss: 0.3809 - accuracy: 0.8678 - val_loss: 0.4870 - val_accuracy: 0.8360 - lr: 6.1267e-04
# Epoch 21/30
# 1563/1563 [==============================] - 25s 16ms/step - loss: 0.3666 - accuracy: 0.8726 - val_loss: 0.4667 - val_accuracy: 0.8425 - lr: 5.6001e-04
# Epoch 22/30
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.3484 - accuracy: 0.8782 - val_loss: 0.4639 - val_accuracy: 0.8439 - lr: 5.0500e-04
# Epoch 23/30
# 1563/1563 [==============================] - 25s 16ms/step - loss: 0.3293 - accuracy: 0.8840 - val_loss: 0.4449 - val_accuracy: 0.8513 - lr: 4.4787e-04
# Epoch 24/30
# 1563/1563 [==============================] - 26s 16ms/step - loss: 0.3130 - accuracy: 0.8917 - val_loss: 0.4429 - val_accuracy: 0.8562 - lr: 3.8886e-04
# Epoch 25/30
# 1563/1563 [==============================] - 25s 16ms/step - loss: 0.3002 - accuracy: 0.8956 - val_loss: 0.4184 - val_accuracy: 0.8585 - lr: 3.2823e-04
# Epoch 26/30
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.2845 - accuracy: 0.9017 - val_loss: 0.4023 - val_accuracy: 0.8650 - lr: 2.6623e-04
# Epoch 27/30
# 1563/1563 [==============================] - 25s 16ms/step - loss: 0.2682 - accuracy: 0.9055 - val_loss: 0.3953 - val_accuracy: 0.8705 - lr: 2.0314e-04
# Epoch 28/30
# 1563/1563 [==============================] - 26s 16ms/step - loss: 0.2528 - accuracy: 0.9132 - val_loss: 0.3902 - val_accuracy: 0.8707 - lr: 1.3922e-04
# Epoch 29/30
# 1563/1563 [==============================] - 25s 16ms/step - loss: 0.2430 - accuracy: 0.9149 - val_loss: 0.3754 - val_accuracy: 0.8743 - lr: 7.4749e-05
# Epoch 30/30
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.2325 - accuracy: 0.9191 - val_loss: 0.3733 - val_accuracy: 0.8740 - lr: 1.0000e-05
# Epoch 1/30
# 1563/1563 [==============================] - 45s 29ms/step - loss: 2.2505 - accuracy: 0.1414 - val_loss: 2.2312 - val_accuracy: 0.1603 - lr: 1.0000e-05
# Epoch 2/30
# 1563/1563 [==============================] - 44s 28ms/step - loss: 2.1687 - accuracy: 0.1768 - val_loss: 2.1466 - val_accuracy: 0.1834 - lr: 2.0800e-04
# Epoch 3/30
# 1563/1563 [==============================] - 44s 28ms/step - loss: 2.0783 - accuracy: 0.2110 - val_loss: 2.0343 - val_accuracy: 0.2217 - lr: 4.0600e-04
# Epoch 4/30
# 1563/1563 [==============================] - 45s 29ms/step - loss: 1.9319 - accuracy: 0.2578 - val_loss: 1.8738 - val_accuracy: 0.2856 - lr: 6.0400e-04
# Epoch 5/30
# 1563/1563 [==============================] - 45s 29ms/step - loss: 1.8203 - accuracy: 0.3028 - val_loss: 1.9692 - val_accuracy: 0.2721 - lr: 8.0200e-04
# Epoch 6/30
# 1563/1563 [==============================] - 45s 29ms/step - loss: 1.7587 - accuracy: 0.3317 - val_loss: 2.1666 - val_accuracy: 0.2812 - lr: 0.0010
# Epoch 7/30
# 1563/1563 [==============================] - 46s 29ms/step - loss: 1.6963 - accuracy: 0.3592 - val_loss: 1.8208 - val_accuracy: 0.3394 - lr: 9.9788e-04
# Epoch 8/30
# 1563/1563 [==============================] - 45s 29ms/step - loss: 1.6334 - accuracy: 0.3883 - val_loss: 1.7190 - val_accuracy: 0.3782 - lr: 9.9153e-04
# Epoch 9/30
# 1563/1563 [==============================] - 45s 28ms/step - loss: 1.5291 - accuracy: 0.4351 - val_loss: 2.0647 - val_accuracy: 0.3366 - lr: 9.8098e-04
# Epoch 10/30
# 1563/1563 [==============================] - 45s 29ms/step - loss: 1.4222 - accuracy: 0.4816 - val_loss: 1.8282 - val_accuracy: 0.4318 - lr: 9.6627e-04
# Epoch 11/30
# 1563/1563 [==============================] - 45s 29ms/step - loss: 1.3344 - accuracy: 0.5146 - val_loss: 1.4368 - val_accuracy: 0.5021 - lr: 9.4746e-04
# Epoch 12/30
# 1563/1563 [==============================] - 46s 29ms/step - loss: 1.2543 - accuracy: 0.5456 - val_loss: 1.2595 - val_accuracy: 0.5502 - lr: 9.2464e-04
# Epoch 13/30
# 1563/1563 [==============================] - 46s 30ms/step - loss: 1.1882 - accuracy: 0.5700 - val_loss: 1.5003 - val_accuracy: 0.4983 - lr: 8.9790e-04
# Epoch 14/30
# 1563/1563 [==============================] - 46s 29ms/step - loss: 1.1360 - accuracy: 0.5880 - val_loss: 1.2183 - val_accuracy: 0.5572 - lr: 8.6737e-04
# Epoch 15/30
# 1563/1563 [==============================] - 46s 29ms/step - loss: 1.0869 - accuracy: 0.6093 - val_loss: 1.0849 - val_accuracy: 0.6140 - lr: 8.3315e-04
# Epoch 16/30
# 1563/1563 [==============================] - 46s 29ms/step - loss: 1.0433 - accuracy: 0.6260 - val_loss: 1.0549 - val_accuracy: 0.6218 - lr: 7.9542e-04
# Epoch 17/30
# 1563/1563 [==============================] - 47s 30ms/step - loss: 1.0003 - accuracy: 0.6398 - val_loss: 1.0267 - val_accuracy: 0.6418 - lr: 7.5432e-04
# Epoch 18/30
# 1563/1563 [==============================] - 47s 30ms/step - loss: 0.9595 - accuracy: 0.6557 - val_loss: 1.0879 - val_accuracy: 0.6170 - lr: 7.1004e-04
# Epoch 19/30
# 1563/1563 [==============================] - 47s 30ms/step - loss: 0.9248 - accuracy: 0.6706 - val_loss: 1.0947 - val_accuracy: 0.6212 - lr: 6.6275e-04
# Epoch 20/30
# 1563/1563 [==============================] - 47s 30ms/step - loss: 0.8887 - accuracy: 0.6843 - val_loss: 1.0080 - val_accuracy: 0.6440 - lr: 6.1267e-04
# Epoch 21/30
# 1563/1563 [==============================] - 46s 29ms/step - loss: 0.8568 - accuracy: 0.6952 - val_loss: 0.8675 - val_accuracy: 0.7008 - lr: 5.6001e-04
# Epoch 22/30
# 1563/1563 [==============================] - 46s 29ms/step - loss: 0.8319 - accuracy: 0.7045 - val_loss: 0.8587 - val_accuracy: 0.6985 - lr: 5.0500e-04
# Epoch 23/30
# 1563/1563 [==============================] - 46s 29ms/step - loss: 0.8029 - accuracy: 0.7163 - val_loss: 0.8074 - val_accuracy: 0.7146 - lr: 4.4787e-04
# Epoch 24/30
# 1563/1563 [==============================] - 46s 29ms/step - loss: 0.7761 - accuracy: 0.7253 - val_loss: 0.8691 - val_accuracy: 0.7019 - lr: 3.8886e-04
# Epoch 25/30
# 1563/1563 [==============================] - 46s 29ms/step - loss: 0.7500 - accuracy: 0.7323 - val_loss: 0.7825 - val_accuracy: 0.7222 - lr: 3.2823e-04
# Epoch 26/30
# 1563/1563 [==============================] - 45s 29ms/step - loss: 0.7343 - accuracy: 0.7384 - val_loss: 0.7357 - val_accuracy: 0.7410 - lr: 2.6623e-04
# Epoch 27/30
# 1563/1563 [==============================] - 45s 29ms/step - loss: 0.7062 - accuracy: 0.7489 - val_loss: 0.7468 - val_accuracy: 0.7399 - lr: 2.0314e-04
# Epoch 28/30
# 1563/1563 [==============================] - 45s 29ms/step - loss: 0.6820 - accuracy: 0.7582 - val_loss: 0.7050 - val_accuracy: 0.7577 - lr: 1.3922e-04
# Epoch 29/30
# 1563/1563 [==============================] - 45s 29ms/step - loss: 0.6679 - accuracy: 0.7630 - val_loss: 0.6960 - val_accuracy: 0.7569 - lr: 7.4749e-05
# Epoch 30/30
# 1563/1563 [==============================] - 45s 29ms/step - loss: 0.6530 - accuracy: 0.7684 - val_loss: 0.6690 - val_accuracy: 0.7663 - lr: 1.0000e-05

# %%
# training and validation data accuracy
acc_20     = history_20.history['accuracy']
loss_20     = history_20.history['loss']

val_loss_20 = history_20.history['val_loss']
val_acc_20 = history_20.history['val_accuracy']

acc_56     = history_56.history['accuracy']
loss_56     = history_56.history['loss']

val_loss_56 = history_56.history['val_loss']
val_acc_56 = history_56.history['val_accuracy']


# plot accuracy
plt.plot(acc_20, label='Training Accuracy 20')
plt.plot(acc_56, label='Training Accuracy 50')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.xlabel('epoch')
plt.ylim([min(plt.ylim()), 1])
plt.title('Training Accuracy')
plt.show()

# plot accuracy
plt.plot(val_acc_20, label='Testing Accuracy 20')
plt.plot(val_acc_56, label='Testing Accuracy 50')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.xlabel('epoch')
plt.ylim([min(plt.ylim()), 1])
plt.title('Testing Accuracy')
plt.show()

plt.plot(loss_20, label='Training Loss 20')
plt.plot(loss_56, label='Training Loss 50')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0, 2.0])
plt.title('Training Loss')
plt.xlabel('epoch')
plt.show()

plt.plot(val_loss_20, label='Testing Loss 20')
plt.plot(val_loss_56, label='Testing Loss 50')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0, 2.0])
plt.title('Testing Loss')
plt.xlabel('epoch')
plt.show()
